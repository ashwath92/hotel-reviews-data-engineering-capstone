# %%
import boto3
import configparser

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY = config.get('default', 'aws_access_key_id')
SECRET = config.get('default','aws_secret_access_key')
ACCESSTOKEN = config.get('default', 'aws_session_token')
REGION = config.get('default', 'aws_region')

# %%
s3 = boto3.client('s3',
                    region_name=REGION,
                    aws_access_key_id=KEY,
                    aws_secret_access_key=SECRET,
                    aws_session_token=ACCESSTOKEN
)

# %%
# Creates in us-east-1 by default
bucket = s3.create_bucket(
    Bucket='hotelreviewslocalplaces'
    #CreateBucketConfiguration={
    #        'LocationConstraint': 'us-east-1'
    #}
)

# %%
# this is how you add a file using an s3 resource, not a client
object = s3.Object('hotelreviewslocalplaces', 'country_indicators.csv')

object.put(Body=open('Data/Cleaned/country_indicators.csv', 'rb'),
          Metadata={'datasource1': 'undp', 'datasource2': 'un data',
                   'datasource3': 'Freedom House', 'datasource4': 'Our World In Data'})
# Out:
# {'ResponseMetadata': {'RequestId': 'DF9A2AEE5F133A96',
#   'HostId': 'OFJMpdT2x5+AXvc7vYcxcLOQ0lgiPab5S8xgXEIOa154WB8tqvXLkIqWWriUk6pv9ykypdEmbX0=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'OFJMpdT2x5+AXvc7vYcxcLOQ0lgiPab5S8xgXEIOa154WB8tqvXLkIqWWriUk6pv9ykypdEmbX0=',
#    'x-amz-request-id': 'DF9A2AEE5F133A96',
#    'date': 'Tue, 16 Jun 2020 23:20:45 GMT',
#    'etag': '"01ab936dc5d3de281e92ec6fb0022d9f"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"01ab936dc5d3de281e92ec6fb0022d9f"'}

# %%
response = s3.put_object(Body=open('Data/Cleaned/country_indicators.csv', 'rb'),
                         Bucket='hotelreviewslocalplaces',
                         Key='country_indicators.csv',
                         Metadata={'datasource1': 'undp', 'datasource2': 'un data',
                                   'datasource3': 'Freedom House', 'datasource4': 'Our World In Data'})
response
# Out:
# {'ResponseMetadata': {'RequestId': '0898D1C2B9BA6E8F',
#   'HostId': 'IRvYvK6+zrfL0mUCIlYt2AOHjPtTNWTeahkbti10hFVp8HtOuri9+GQoIK3AWmRbtPhbV/sfA2E=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'IRvYvK6+zrfL0mUCIlYt2AOHjPtTNWTeahkbti10hFVp8HtOuri9+GQoIK3AWmRbtPhbV/sfA2E=',
#    'x-amz-request-id': '0898D1C2B9BA6E8F',
#    'date': 'Wed, 17 Jun 2020 00:02:35 GMT',
#    'etag': '"01ab936dc5d3de281e92ec6fb0022d9f"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"01ab936dc5d3de281e92ec6fb0022d9f"'}

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.functions import row_number,lit
from pyspark.sql.window import Window
from pyspark.sql.types import StringType, IntegerType, FloatType, StructType, DoubleType, DecimalType

# %%
spark = SparkSession.builder\
                     .config("spark.jars.packages","org.apache.hadoop:hadoop-aws:2.7.0")\
                     .getOrCreate()

# %%
#df_airports = spark.read.csv('Data/Cleaned/airports.csv', header=True)
df_airports = spark.read.parquet('Data/Cleaned/airports.parquet')

# %%
df_airports.count()
# Out:
# 5908

# %%
df_airports.limit(10).toPandas()
# Out:
#   AirportID           Type                AirportName Municipality ISOCountry  \
# 0   DE-0002  small_airport  Flugplatz Torgau-Beilrode       Torgau         DE
# 1   DE-0004  small_airport            Gransee Airport      Gransee         DE
# 2   DE-0005  small_airport           Warngau Airfield     MÃ¼nchen         DE
# 3   DE-0006  small_airport            Locktow Airport      Locktow         DE
# 4   DE-0029  small_airport        Berlinchen Airfield   Berlinchen         DE
# 5   DE-0038  small_airport    Utscheid Segelflugplatz      Bitburg         DE
# 6   DE-0039  small_airport            Aichach Airport      Aichach         DE
# 7   DE-0040  small_airport        Zierenberg Airfield   Zierenberg         DE
# 8   DE-0041  small_airport      Zellhausen Gliderport   Zellhausen         DE
# 9   DE-0042  small_airport          WÃ¼lzburg Airport         None         DE
#
#   Continent ISORegion   Latitude  Longitude ElevationInFeet GPSCode IATACode  \
# 0        EU     DE-SN  51.571167  13.052167             269    EDOG     None
# 1        EU     DE-BR  53.006699  13.205000             164    None     None
# 2        EU     DE-BY  47.825011  11.703733            2380    None     None
# 3        EU     DE-BR  52.116390  12.709444             213    None     None
# 4        EU     DE-BR  53.225178  12.565527            None    None     None
# 5        EU     DE-RP  49.997778   6.342778            1390    None     None
# 6        EU     DE-BY  48.471798  11.134349            1445    None     None
# 7        EU     DE-HE  51.367000   9.336000            1450    None     None
# 8        EU     DE-HE  50.018845   8.984376             370    None     None
# 9        EU     DE-BY  49.025851  11.018746            2027    None     None
#
#   LocalCode  Country
# 0      None  Germany
# 1      None  Germany
# 2      None  Germany
# 3      None  Germany
# 4      None  Germany
# 5      None  Germany
# 6      None  Germany
# 7      None  Germany
# 8      None  Germany
# 9      None  Germany

# %%
df_hotels = spark.read.parquet('Data/Cleaned/hotels.parquet')

# %%
df_hotels.count()
# Out:
# 1493

# %%
df_hotels.limit(5).toPandas()
# Out:
#    HotelID                               HotelName  \
# 0      144                        Relais Du Louvre
# 1      153       Four Seasons Hotel George V Paris
# 2      420  BEST WESTERN Premier Trocadéro La Tour
# 3     1013  Novotel Paris Centre Gare Montparnasse
# 4      499                  Novotel Barcelona City
#
#                                         HotelAddress           Phone Price  \
# 0  19 Rue Des Pretres Saint Germain L Auxerrois 1...  01 42 60 34 22  None
# 1      31 Avenue George V 8th arr 75008 Paris France            None  None
# 2     5 bis rue Massenet 16th arr 75016 Paris France  01 45 24 43 03  None
# 3     17 Rue Du Cotentin 15th arr 75015 Paris France            None  None
# 4  Avenida Diagonal 201 Sant Mart 08018 Barcelona...    933 26 24 99  None
#
#                         OriginalHotelName  \
# 0                        Relais Du Louvre
# 1       Four Seasons Hotel George V Paris
# 2  Best Western Premier Trocadero La Tour
# 3  Novotel Paris Centre Gare Montparnasse
# 4                  Novotel Barcelona City
#
#                                       GoogleAddress    Latitude  Longitude  \
# 0            [3 Rue du Louvre, 75001 Paris, France]  48.8592264   2.340996
# 1                                              None  48.8687512  2.3001692
# 2             [5 Rue Massenet, 75016 Paris, France]  48.8583127  2.2795075
# 3                                              None   48.838484  2.3150904
# 4  [Avinguda Diagonal, 199, 08018 Barcelona, Spain]  41.4038774  2.1911894
#
#             gPlusPlaceId NearestAirportID       MondayHours      TuesdayHours  \
# 0  113034259603416119057             LFPB  8:00 am--9:00 pm  8:00 am--9:00 pm
# 1                   None             LFPV              None              None
# 2  107754700607079935569             LFPV              None              None
# 3                   None             LFPV              None              None
# 4  115909827232414886024             LELL     1:00--4:00 pm     1:00--4:00 pm
#
#      WednesdayHours     ThursdayHours       FridayHours     SaturdayHours  \
# 0  8:00 am--9:00 pm  8:00 am--9:00 pm  8:00 am--9:00 pm  8:00 am--9:00 pm
# 1              None              None              None              None
# 2              None              None              None              None
# 3              None              None              None              None
# 4     1:00--4:00 pm     1:00--4:00 pm     1:00--4:00 pm     1:00--4:00 pm
#
#         SundayHours Country
# 0  8:00 am--9:00 pm  France
# 1              None  France
# 2              None  France
# 3              None  France
# 4     1:00--4:00 pm   Spain

# %%
df_hotel_reviews = spark.read.json('Data/Cleaned/reviews.jsonl')

# %%
df_hotel_reviews.count()
# Out:
# 515349

# %%
df_hotel_reviews.limit(5).toPandas()
# Out:
#    AverageScore  HotelID                                     NegativeReview  \
# 0           7.7      298  Rooms are nice but for elderly a bit difficult...
# 1           7.7      298  My room was dirty and I was afraid to walk bar...
# 2           7.7      298                                        No Negative
# 3           7.7      298       Beds sucked Air conditioner too loud for use
# 4           7.7     1199     for the time we were there everything was good
#
#    NumRatings  NumReviews                                     PositiveReview  \
# 0         194        1403  Location was good and staff were ok It is cute...
# 1         194        1403  Great location in nice surroundings the bar an...
# 2         194        1403  Great restaurant bar very green area you dine ...
# 3         194        1403                         Nice property and building
# 4        1058        4380  Rooms lovely and tastefully decorated staff ve...
#
#    ReviewDate  ReviewNegativeWordsCount  ReviewPositiveWordsCount  \
# 0  2017-07-31                        42                        21
# 1  2017-07-31                       210                        26
# 2  2017-07-31                         0                        18
# 3  2017-07-31                        10                         6
# 4  2017-07-31                        10                        16
#
#   ReviewerNationality  ReviewerScore  \
# 0           Australia            7.1
# 1      United Kingdom            3.8
# 2      United Kingdom            9.6
# 3              Canada            7.5
# 4      United Kingdom           10.0
#
#                                                 Tags  \
# 0  [' Leisure trip ', ' Family with young childre...
# 1  [' Leisure trip ', ' Solo traveler ', ' Duplex...
# 2  [' Leisure trip ', ' Group ', ' Duplex Double ...
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...
# 4  [' Business trip ', ' Couple ', ' Deluxe Doubl...
#
#    TotalNumReviewsByReviewer
# 0                          9
# 1                          1
# 2                          1
# 3                          1
# 4                          9
